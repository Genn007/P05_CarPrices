# %% [markdown]
# # Расчет цены на автомобиль
# ### Книга 02 - сбор данных с сайта авто-ру.
#
# Постановка задачи:
# Необходимо разработать модель, которая бы рассчитывала цену на выставленный на продажу автомобиль.  По условиям учебной задачи обучающих данных в явном виде не предоставлено. Только тестовые, собранные на авто-ру больше года назад. Необходимо самостоятельно разработать программу, которая бы собирала данные по объявлениям на том же сайте авто.ру. Дополнительная сложность - количество данных. Оцениваться работа будет по порядка 35к записей. Необходимо собрать порядка 140 тыс записей.  На самом сайте автору сейчас актуально порядка 90к объявлений.
#
# Поиск в сети сформировал следующую картину:
# - Есть готовая работающая программа сбора данных с сайта auto-ru, требующая косметической доработки. Автор (rzabolotin) выложил ее на github в составе своего решения. Программа сформирована для самостоятельного запуска интерпретатором Python и вызывает вопросы в части сбора данных.
# - Существуют данные, собранные rzabolotin примерно 21-01-08, которые содержат дубликаты. После отсева остается примерно 35к записей.
# - Существуют данные от авторов учебной задачи, которые сохранены совсем в ином формате и вероятно собраны до 20-09-09.
# - На kaggle найден еще один источник данных от Kiril & Tanya, датированный примерно 21-08-24.
# - Данные теста действительно частично устарели - записи не находятся.
#
# Ближайший план работы:
# - Перенести программу сбора данных в ноутбук из соображений большей интерактивности работы в среде DataSpell-EAP, внести в нее косметические коррективы и вероятно исправить стратегию сбора данных.
# - Собрать какое-то количество данных по состоянию на текущий момент.
# - Объединить воедино наборы данных от авторов учебной задачи, rzabolotin, kiril&tanyaб и мои собственные.

# %% [markdown]
# # 1. Сбор данных с сайта auto.ru

# %% [markdown]
# #### Декларации и импорт библиотек
#
# Копирование в ноутбук найденной унаследованной (legacy) программы парсинга сайта.  В ней понадобится сделать исправления - привести в соответствие с новой структурой сайта.

# %%
import argparse
from collections import namedtuple, defaultdict
from csv import DictWriter
import json
from pathlib import Path
import time, random
import pandas as pd

import requests
from loguru import logger

# %%
def get_headers():
    headers = '''
Host: auto.ru
Connection: keep-alive
Content-Length: 99
x-requested-with: fetch
x-client-date: 1603066469874
x-csrf-token: c23073bb4cd65413662a41bd460fd8317459fe3ce6d83db1
x-page-request-id: 3c4800b60eb9e8c568e5a515f5cd4872
content-type: application/json
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36
x-client-app-version: 202010.16.122434
Accept: */*
Origin: https://auto.ru
Sec-Fetch-Site: same-origin
Sec-Fetch-Mode: same-origin
Sec-Fetch-Dest: empty
Referer: https://auto.ru/cars/bmw/all/?output_type=list&page=1
Accept-Encoding: gzip, deflate, br
Accept-Language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7
Cookie: autoru_sid=a%3Ag5f88f7d72b1bif6t0m99h0krigjgs2e.a783a85b576c8a7acaea4faafaa81ffc%7C1602811863959.604800.QhhqH0HWfM4BPWrsvjyfIg.8EXrpUR7Bq1a2gOSCnsb0HnXxvmHbYB9eF5Uz5o_bZE; autoruuid=g5f88f7d72b1bif6t0m99h0krigjgs2e.a783a85b576c8a7acaea4faafaa81ffc; suid=63abf8672f4a9e550bb96dd00b95ad21.8e155bfb838a5227bdd9dea1d2cbdc3e; _ym_uid=1602811867719278329; yuidcs=1; crookie=PZwS3/iYq2PFIw/dbrsqDVB/0e2v79Xe/8RsG6ySC8Djcl+mh/UCjYohgODaSkw7rMa6O9v7+RD56YSQKE2fhSkWxV8=; cmtchd=MTYwMjgyODMxMjMwNQ==; bltsr=1; yuidlt=1; yandexuid=360949521578055883; my=YwA%3D; _ym_isad=1; promo-app-banner-shown=1; promo-header-counter=4; _csrf_token=c23073bb4cd65413662a41bd460fd8317459fe3ce6d83db1; from=direct; X-Vertis-DC=myt; _ym_wasSynced=%7B%22time%22%3A1603066366683%2C%22params%22%3A%7B%22eu%22%3A0%7D%2C%22bkParams%22%3A%7B%7D%7D; gdpr=0; _ym_visorc_22753222=b; from_lifetime=1603066463083; _ym_d=1603066470'''
    headers = {line.split(': ')[0]: line.split(': ')[1] for line in headers.strip().split('\n')}
    return headers

# %%
def get_data_from_site(pange_num: int, brand: str) -> dict:
    """ получает данные о автомобилях с авто.ру, номер страницы передан в параметре page_num
    возвращает полученный с сайта json """

    base_url = 'https://auto.ru/-/ajax/desktop/listing/'
    params = dict(category='cars', section="all", output_type="list", page=pange_num,
                  catalog_filter=[{'mark': brand}], geo_id=[213], geo_radius=800)
    r = requests.post(base_url, json=params, headers=get_headers())
    r.raise_for_status()
    return r.json()

# %%
def add_car_data(car_data: list, data_json: dict):
    """ разбирает данные из переданного объекта data_json
    из массива offers, формирует объекты CarInfo и
    добавляет их в список car_data"""

    if 'offers' not in data_json:
        return

    for car in data_json['offers']:
        if 'configuration' not in car['vehicle_info']:
            continue

        body_type_human = car['vehicle_info']['configuration']['human_name']
        body_type = car['vehicle_info']['configuration']['body_type']
        transmission = car['vehicle_info']['tech_param']['transmission']
        engine_volume = car['vehicle_info']['tech_param']['displacement']
        engine_volume = round(float(engine_volume) / 1000, 1)

        try:
            purchase_date = car['documents']['purchase_date']
        except KeyError:
            purchase_date = None

        try:
            owners_number = car['documents']['owners_number']
        except KeyError:
            owners_number = None

        try:
            description = car['description']
        except KeyError:
            description = None
        try:
            pts = car['documents']['pts']
        except KeyError:
            pts = None
        try:
            price = car['price_info']['RUR']
        except KeyError:
            continue

        brand = car['vehicle_info']['mark_info']['name']
        # model = car['vehicle_info']['model_info']['name']
        model = car['vehicle_info']['model_info']['code']
        sell_id = car['saleId']
        section = car['section']
        # Здесь ошибка - сохраняются адреса в старом формате ссылок авто-ру,
        # в частности "5 серии" вместо текущей "5er"
        car_url = f'https://auto.ru/cars/{section}/sale/{brand.lower()}/{model.lower()}/{sell_id}/'

        info = CarInfo(bodyType=body_type_human,
                       brand=brand,
                       car_url=car_url,
                       image=car['state']['image_urls'][0]['sizes']['small'],
                       color=car['color_hex'],
                       complectation_dict=car['vehicle_info']['complectation'],
                       equipment_dict=car['vehicle_info']['equipment'],
                       model_info=car['vehicle_info']['model_info'],
                       model_name=model,
                       location=car['seller']['location']['region_info']['name'],
                       parsing_unixtime=car['additional_info']['fresh_date'],
                       priceCurrency=car['price_info']['currency'],
                       sell_id=sell_id,
                       super_gen=car['vehicle_info']['super_gen'],
                       vendor=car['vehicle_info']['vendor'],
                       fuelType=car['vehicle_info']['tech_param']['engine_type'],
                       modelDate=car['vehicle_info']['super_gen']['year_from'],
                       name=car['vehicle_info']['tech_param']['human_name'],
                       numberOfDoors=car['vehicle_info']['configuration']['doors_count'],
                       productionDate=car['documents']['year'],
                       vehicleConfiguration=body_type + " " + transmission + " " + str(engine_volume),
                       vehicleTransmission=transmission,
                       engineDisplacement=str(engine_volume) + ' LTR',
                       enginePower=str(car['vehicle_info']['tech_param']['power']) + ' N12',
                       description=description,
                       mileage=car['state']['mileage'],
                       Привод=car['vehicle_info']['tech_param']['gear_type'],
                       Руль=car['vehicle_info']['steering_wheel'],
                       Состояние=car['state']['state_not_beaten'],
                       Владельцы=owners_number,
                       ПТС=pts,
                       Таможня=car['documents']['custom_cleared'],
                       Владение=purchase_date,
                       price=price
                       )
        car_data.append(info)

# %%
def write_to_csv(car_data: list, output_folder_path: Path, page_num: int):
    """Записывает информацию о машинах из car_data в файл формата csv
    output_folder_path задает папку для сохранения
    page_num - нужен для наименования файла"""

    if not car_data:
        return

    filename = output_folder_path / f'train_{page_num}.csv'
    filename = output_folder_path / f'data.csv'
    #
    with open(filename, 'a', encoding='utf-8', newline='') as f:
        logger.info(f'writing {filename}, содержащий {len(car_data)} записей')
        writer = DictWriter(f, fieldnames=columns)
        writer.writeheader()
        writer.writerows([car._asdict() for car in car_data])
        f.close()

# %%
def pickup_brand(brand_stats: dict) -> str:
    cars_count = sum(val for val in brand_stats.values())
    brand_proportion = {key: val / cars_count for key, val in brand_stats.items()}

    proportion_in_test_copy = proportion_in_test.copy()
    for key, val in brand_proportion.items():
        proportion_in_test_copy[key] -= val

    return sorted(proportion_in_test_copy.items(),
                  key=lambda x: x[1],
                  reverse=True)[0][0] # first element, key of pair key:value

# %%
"""
LEGACY  Function!!!  Сделаем ее некомпилируемой - буква d в определении имени функции пропущена.
def parse_data(n_pages, output_folder, save_json, json_folder):
    """Входная точка в программу. Содержит верхнеуровневую логику.
    Собирает информацию с сайта, парсит и сохраняет в формате csv"""

    logger.info('Starting parse data from auto.ru about cars')

    if save_json:
        json_folder_path = Path(json_folder)
        json_folder_path.mkdir(parents=True, exist_ok=True)

    output_folder_path = Path(output_folder)
    output_folder_path.mkdir(parents=True, exist_ok=True)

    car_data = []
    brand_stats = defaultdict(lambda: 1)

    for page_num in range(1, n_pages + 1):

        brand = pickup_brand(brand_stats)

        logger.info(f'processing page: {page_num} {brand} {brand_stats[brand]}')
        try:
            data_json = get_data_from_site(brand_stats[brand], brand)
        except Exception as e:
            logger.error(f"Error in parsing: {e}")
            continue

        brand_stats[brand] += 1

        if save_json:
            with open(json_folder_path / f'page_{page_num}.json', 'w', encoding='utf-8') as f:
                json.dump(data_json, f)

        add_car_data(car_data, data_json)

        if page_num % 50 == 0:
            write_to_csv(car_data, output_folder_path, page_num)
            car_data = []

    write_to_csv(car_data, output_folder_path, page_num)

    logger.info('parsing successfully finished')
"""
# Out:
#   File "/var/folders/gb/vp2kjpjj7kxgkxk0ltq2p87h0000gn/T/ipykernel_98844/819779792.py", line 2
#     ef parse_data(n_pages, output_folder, save_json, json_folder):
#        ^
# SyntaxError: invalid syntax

# %%
"""
Это вызов кода в оригинальной отдельной программе.
Сохранен для истории
Автор предлагал вызывать программу из интерпретатора командной строки

python autoru_parser.ry -o outputdirectory  NNN


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("n_pages", help="number of pages to parse", type=int)
    parser.add_argument("-o", "--output_folder", help='folder to save parsed csv files', type=str, default='.')
    parser.add_argument("-j", "--save_json", help="save json files", action="store_true")
    parser.add_argument("--json_folder", help='folder for json files', type=str, default='json')
    args = parser.parse_args()

    parse_data(args.n_pages,
               args.output_folder,
               args.save_json,
               args.json_folder)


if __name__ == '__main__':
    main()
"""
# Out:
# '\nЭто вызов кода в оригинальной отдельной программе.\nСохранен для истории\nАвтор предлагал вызывать программу из интерпретатора командной строки\n\npython autoru_parser.ry -o outputdirectory  NNN\n\n\ndef main():\n    parser = argparse.ArgumentParser()\n    parser.add_argument("n_pages", help="number of pages to parse", type=int)\n    parser.add_argument("-o", "--output_folder", help=\'folder to save parsed csv files\', type=str, default=\'.\')\n    parser.add_argument("-j", "--save_json", help="save json files", action="store_true")\n    parser.add_argument("--json_folder", help=\'folder for json files\', type=str, default=\'json\')\n    args = parser.parse_args()\n\n    parse_data(args.n_pages,\n               args.output_folder,\n               args.save_json,\n               args.json_folder)\n\n\nif __name__ == \'__main__\':\n    main()\n'

# %%
"""
Это определения из унаследованной программы. Часть из них будет иметь значение
"""
columns = ['bodyType', 'brand', 'car_url', 'color', 'complectation_dict', 'description', 'engineDisplacement',
           'enginePower', 'location',
           'equipment_dict', 'fuelType', 'image', 'mileage', 'modelDate', 'model_info', 'model_name', 'name',
           'numberOfDoors', 'parsing_unixtime', 'priceCurrency', 'productionDate', 'sell_id', 'super_gen',
           'vehicleConfiguration', 'vehicleTransmission', 'vendor', 'Владельцы', 'Владение', 'ПТС', 'Привод',
           'Руль', 'Состояние', 'Таможня', 'price']

CarInfo = namedtuple('Car', columns)

brand_in_test = {
    'BMW': 4473,
    'VOLKSWAGEN': 4404,
    'NISSAN': 4393,
    'MERCEDES': 4180,
    'TOYOTA': 3913,
    'AUDI': 3421,
    'MITSUBISHI': 2843,
    'SKODA': 2741,
    'VOLVO': 1463,
    'HONDA': 1150,
    'INFINITI': 871,
    'LEXUS': 834
}
cars_in_test = sum(val for val in brand_in_test.values())
proportion_in_test = {key: val / cars_in_test for key, val in brand_in_test.items()}

# %% [markdown]
# На этом legacy код закончился.  Для сбора данных я делаю новую процедуру по аналогии с унаследованной, в которой отключаю json и прочие бантики.

# %%
def parse_data_02(n_pages, output_folder, brand ): # , save_json, json_folder):

    logger.info('Starting parse data from auto.ru about cars')


    output_folder_path = Path(output_folder)
    output_folder_path.mkdir(parents=True, exist_ok=True)

    car_data = []
    brand_stats = defaultdict(lambda: 1)

    for page_num in range(1, n_pages + 1):


        logger.info(f'processing page: {page_num} {brand}) # {brand_stats[brand]}')
        try:
            data_json = get_data_from_site(page_num, brand)
        except Exception as e:
            logger.error(f"Error in parsing: {e}")
            continue

        add_car_data(car_data, data_json)

        if page_num % 50 == 0:
            write_to_csv(car_data, output_folder_path, page_num)
            car_data = []

        time.sleep(random.random()*2)

    write_to_csv(car_data, output_folder_path, page_num)

    logger.info('parsing successfully finished')

# %%
parse_data_02(99,'output','AUDI')
# Out:
# 2021-11-20 18:18:47.182 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-20 18:18:47.184 | INFO     | __main__:parse_data_02:21 - processing page: 1 AUDI) # 1
# 2021-11-20 18:18:48.106 | INFO     | __main__:parse_data_02:21 - processing page: 2 AUDI) # 1
# 2021-11-20 18:18:48.941 | INFO     | __main__:parse_data_02:21 - processing page: 3 AUDI) # 1
# 2021-11-20 18:18:49.978 | INFO     | __main__:parse_data_02:21 - processing page: 4 AUDI) # 1
# 2021-11-20 18:18:50.817 | INFO     | __main__:parse_data_02:21 - processing page: 5 AUDI) # 1
# 2021-11-20 18:18:51.797 | INFO     | __main__:parse_data_02:21 - processing page: 6 AUDI) # 1
# 2021-11-20 18:18:52.823 | INFO     | __main__:parse_data_02:21 - processing page: 7 AUDI) # 1
# 2021-11-20 18:18:53.658 | INFO     | __main__:parse_data_02:21 - processing page: 8 AUDI) # 1
# 2021-11-20 18:18:54.699 | INFO     | __main__:parse_data_02:21 - processing page: 9 AUDI) # 1
# 2021-11-20 18:18:55.822 | INFO     | __main__:parse_data_02:21 - processing page: 10 AUDI) # 1
# 2021-11-20 18:18:57.314 | INFO     | __main__:parse_data_02:21 - processing page: 11 AUDI) # 1
# 2021-11-20 18:18:58.365 | INFO     | __main__:parse_data_02:21 - processing page: 12 AUDI) # 1
# 2021-11-20 18:18:59.190 | INFO     | __main__:parse_data_02:21 - processing page: 13 AUDI) # 1
# 2021-11-20 18:19:00.393 | INFO     | __main__:parse_data_02:21 - processing page: 14 AUDI) # 1
# 2021-11-20 18:19:01.389 | INFO     | __main__:parse_data_02:21 - processing page: 15 AUDI) # 1
# 2021-11-20 18:19:02.581 | INFO     | __main__:parse_data_02:21 - processing page: 16 AUDI) # 1
# 2021-11-20 18:19:04.200 | INFO     | __main__:parse_data_02:21 - processing page: 17 AUDI) # 1
# 2021-11-20 18:19:05.296 | INFO     | __main__:parse_data_02:21 - processing page: 18 AUDI) # 1
# 2021-11-20 18:19:06.602 | INFO     | __main__:parse_data_02:21 - processing page: 19 AUDI) # 1
# 2021-11-20 18:19:07.391 | INFO     | __main__:parse_data_02:21 - processing page: 20 AUDI) # 1
# 2021-11-20 18:19:08.416 | INFO     | __main__:parse_data_02:21 - processing page: 21 AUDI) # 1
# 2021-11-20 18:19:09.156 | INFO     | __main__:parse_data_02:21 - processing page: 22 AUDI) # 1
# 2021-11-20 18:19:09.946 | INFO     | __main__:parse_data_02:21 - processing page: 23 AUDI) # 1
# 2021-11-20 18:19:11.002 | INFO     | __main__:parse_data_02:21 - processing page: 24 AUDI) # 1
# 2021-11-20 18:19:11.899 | INFO     | __main__:parse_data_02:21 - processing page: 25 AUDI) # 1
# 2021-11-20 18:19:12.603 | INFO     | __main__:parse_data_02:21 - processing page: 26 AUDI) # 1
# 2021-11-20 18:19:14.213 | INFO     | __main__:parse_data_02:21 - processing page: 27 AUDI) # 1
# 2021-11-20 18:19:15.089 | INFO     | __main__:parse_data_02:21 - processing page: 28 AUDI) # 1
# 2021-11-20 18:19:15.807 | INFO     | __main__:parse_data_02:21 - processing page: 29 AUDI) # 1
# 2021-11-20 18:19:16.568 | INFO     | __main__:parse_data_02:21 - processing page: 30 AUDI) # 1
# 2021-11-20 18:19:17.296 | INFO     | __main__:parse_data_02:21 - processing page: 31 AUDI) # 1
# 2021-11-20 18:19:18.630 | INFO     | __main__:parse_data_02:21 - processing page: 32 AUDI) # 1
# 2021-11-20 18:19:19.913 | INFO     | __main__:parse_data_02:21 - processing page: 33 AUDI) # 1
# 2021-11-20 18:19:20.795 | INFO     | __main__:parse_data_02:21 - processing page: 34 AUDI) # 1
# 2021-11-20 18:19:21.611 | INFO     | __main__:parse_data_02:21 - processing page: 35 AUDI) # 1
# 2021-11-20 18:19:22.535 | INFO     | __main__:parse_data_02:21 - processing page: 36 AUDI) # 1
# 2021-11-20 18:19:23.491 | INFO     | __main__:parse_data_02:21 - processing page: 37 AUDI) # 1
# 2021-11-20 18:19:24.387 | INFO     | __main__:parse_data_02:21 - processing page: 38 AUDI) # 1
# 2021-11-20 18:19:26.378 | INFO     | __main__:parse_data_02:21 - processing page: 39 AUDI) # 1
# 2021-11-20 18:19:27.804 | INFO     | __main__:parse_data_02:21 - processing page: 40 AUDI) # 1
# 2021-11-20 18:19:28.793 | INFO     | __main__:parse_data_02:21 - processing page: 41 AUDI) # 1
# 2021-11-20 18:19:29.630 | INFO     | __main__:parse_data_02:21 - processing page: 42 AUDI) # 1
# 2021-11-20 18:19:30.794 | INFO     | __main__:parse_data_02:21 - processing page: 43 AUDI) # 1
# 2021-11-20 18:19:31.707 | INFO     | __main__:parse_data_02:21 - processing page: 44 AUDI) # 1
# 2021-11-20 18:19:32.387 | INFO     | __main__:parse_data_02:21 - processing page: 45 AUDI) # 1
# 2021-11-20 18:19:33.746 | INFO     | __main__:parse_data_02:21 - processing page: 46 AUDI) # 1
# 2021-11-20 18:19:34.773 | INFO     | __main__:parse_data_02:21 - processing page: 47 AUDI) # 1
# 2021-11-20 18:19:35.410 | INFO     | __main__:parse_data_02:21 - processing page: 48 AUDI) # 1
# 2021-11-20 18:19:36.268 | INFO     | __main__:parse_data_02:21 - processing page: 49 AUDI) # 1
# 2021-11-20 18:19:37.297 | INFO     | __main__:parse_data_02:21 - processing page: 50 AUDI) # 1
# 2021-11-20 18:19:38.045 | INFO     | __main__:write_to_csv:11 - writing output/train_50.csv, содержащий 1850 записей
# 2021-11-20 18:19:38.538 | INFO     | __main__:parse_data_02:21 - processing page: 51 AUDI) # 1
# 2021-11-20 18:19:39.706 | INFO     | __main__:parse_data_02:21 - processing page: 52 AUDI) # 1
# 2021-11-20 18:19:40.849 | INFO     | __main__:parse_data_02:21 - processing page: 53 AUDI) # 1
# 2021-11-20 18:19:41.681 | INFO     | __main__:parse_data_02:21 - processing page: 54 AUDI) # 1
# 2021-11-20 18:19:42.688 | INFO     | __main__:parse_data_02:21 - processing page: 55 AUDI) # 1
# 2021-11-20 18:19:43.523 | INFO     | __main__:parse_data_02:21 - processing page: 56 AUDI) # 1
# 2021-11-20 18:19:44.489 | INFO     | __main__:parse_data_02:21 - processing page: 57 AUDI) # 1
# 2021-11-20 18:19:45.296 | INFO     | __main__:parse_data_02:21 - processing page: 58 AUDI) # 1
# 2021-11-20 18:19:46.384 | INFO     | __main__:parse_data_02:21 - processing page: 59 AUDI) # 1
# 2021-11-20 18:19:47.422 | INFO     | __main__:parse_data_02:21 - processing page: 60 AUDI) # 1
# 2021-11-20 18:19:48.569 | INFO     | __main__:parse_data_02:21 - processing page: 61 AUDI) # 1
# 2021-11-20 18:19:49.584 | INFO     | __main__:parse_data_02:21 - processing page: 62 AUDI) # 1
# 2021-11-20 18:19:50.661 | INFO     | __main__:parse_data_02:21 - processing page: 63 AUDI) # 1
# 2021-11-20 18:19:52.007 | INFO     | __main__:parse_data_02:21 - processing page: 64 AUDI) # 1
# 2021-11-20 18:19:53.296 | INFO     | __main__:parse_data_02:21 - processing page: 65 AUDI) # 1
# 2021-11-20 18:19:54.126 | INFO     | __main__:parse_data_02:21 - processing page: 66 AUDI) # 1
# 2021-11-20 18:19:55.399 | INFO     | __main__:parse_data_02:21 - processing page: 67 AUDI) # 1
# 2021-11-20 18:19:56.283 | INFO     | __main__:parse_data_02:21 - processing page: 68 AUDI) # 1
# 2021-11-20 18:19:57.542 | INFO     | __main__:parse_data_02:21 - processing page: 69 AUDI) # 1
# 2021-11-20 18:19:58.262 | INFO     | __main__:parse_data_02:21 - processing page: 70 AUDI) # 1
# 2021-11-20 18:19:58.970 | INFO     | __main__:parse_data_02:21 - processing page: 71 AUDI) # 1
# 2021-11-20 18:20:00.339 | INFO     | __main__:parse_data_02:21 - processing page: 72 AUDI) # 1
# 2021-11-20 18:20:01.376 | INFO     | __main__:parse_data_02:21 - processing page: 73 AUDI) # 1
# 2021-11-20 18:20:02.409 | INFO     | __main__:parse_data_02:21 - processing page: 74 AUDI) # 1
# 2021-11-20 18:20:03.394 | INFO     | __main__:parse_data_02:21 - processing page: 75 AUDI) # 1
# 2021-11-20 18:20:04.119 | INFO     | __main__:parse_data_02:21 - processing page: 76 AUDI) # 1
# 2021-11-20 18:20:04.898 | INFO     | __main__:parse_data_02:21 - processing page: 77 AUDI) # 1
# 2021-11-20 18:20:06.032 | INFO     | __main__:parse_data_02:21 - processing page: 78 AUDI) # 1
# 2021-11-20 18:20:06.777 | INFO     | __main__:parse_data_02:21 - processing page: 79 AUDI) # 1
# 2021-11-20 18:20:07.892 | INFO     | __main__:parse_data_02:21 - processing page: 80 AUDI) # 1
# 2021-11-20 18:20:08.761 | INFO     | __main__:parse_data_02:21 - processing page: 81 AUDI) # 1
# 2021-11-20 18:20:09.974 | INFO     | __main__:parse_data_02:21 - processing page: 82 AUDI) # 1
# 2021-11-20 18:20:10.816 | INFO     | __main__:parse_data_02:21 - processing page: 83 AUDI) # 1
# 2021-11-20 18:20:11.809 | INFO     | __main__:parse_data_02:21 - processing page: 84 AUDI) # 1
# 2021-11-20 18:20:13.495 | INFO     | __main__:parse_data_02:21 - processing page: 85 AUDI) # 1
# 2021-11-20 18:20:14.241 | INFO     | __main__:parse_data_02:21 - processing page: 86 AUDI) # 1
# 2021-11-20 18:20:14.945 | INFO     | __main__:parse_data_02:21 - processing page: 87 AUDI) # 1
# 2021-11-20 18:20:16.248 | INFO     | __main__:parse_data_02:21 - processing page: 88 AUDI) # 1
# 2021-11-20 18:20:17.582 | INFO     | __main__:parse_data_02:21 - processing page: 89 AUDI) # 1
# 2021-11-20 18:20:18.691 | INFO     | __main__:parse_data_02:21 - processing page: 90 AUDI) # 1
# 2021-11-20 18:20:19.470 | INFO     | __main__:parse_data_02:21 - processing page: 91 AUDI) # 1
# 2021-11-20 18:20:20.719 | INFO     | __main__:parse_data_02:21 - processing page: 92 AUDI) # 1
# 2021-11-20 18:20:22.114 | INFO     | __main__:parse_data_02:21 - processing page: 93 AUDI) # 1
# 2021-11-20 18:20:23.282 | INFO     | __main__:parse_data_02:21 - processing page: 94 AUDI) # 1
# 2021-11-20 18:20:24.212 | INFO     | __main__:parse_data_02:21 - processing page: 95 AUDI) # 1
# 2021-11-20 18:20:24.982 | INFO     | __main__:parse_data_02:21 - processing page: 96 AUDI) # 1
# 2021-11-20 18:20:25.951 | INFO     | __main__:parse_data_02:21 - processing page: 97 AUDI) # 1
# 2021-11-20 18:20:27.126 | INFO     | __main__:parse_data_02:21 - processing page: 98 AUDI) # 1
# 2021-11-20 18:20:28.381 | INFO     | __main__:parse_data_02:21 - processing page: 99 AUDI) # 1
# 2021-11-20 18:20:29.645 | INFO     | __main__:write_to_csv:11 - writing output/train_99.csv, содержащий 1813 записей
# 2021-11-20 18:20:30.166 | INFO     | __main__:parse_data_02:43 - parsing successfully finished

# %% [markdown]
# Проба прошла отлично.  Стерты еще несколько проб.  По ходу сбора данных возникло несколько вопросов.
#
# 1.Как собирать данные - все значимые марки (по мнению автора условий) или только марки, которые есть в тестовом наборе?
#
# 2. На сайте автору отображается информация на 99 страницах, но данных по некоторым маркам больше. Как скачать максимальное количество данных по маркам?
#
# Принято два решения:
#
# 1. Сделать два набора данных - все значимые марки (36 брендов) и выборочные марки для теста (12 брендов).  Потом в ходе экспериментов понять важность 24 лишних брендов.
# 2. Скачивать весь объем данных по маркам несколько раз с перерывами 4-8 часов. Потом объединить эти наборы в один и устранить дубликаты.  Результат купажа и сепажа сохранить в виде файла для дальнейшего использования.

# %%
brands = ['AUDI', 'BMW', 'CADILLAC', 'CHERY', 'CHEVROLET', 'CHRYSLER', 'CITROEN', 'DAEWOO', 'DODGE', 'FORD', 'GEELY', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP', 'KIA', 'LEXUS', 'MAZDA', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SKODA', 'SUBARU', 'SUZUKI', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GREAT_WALL', 'LAND_ROVER', 'MERCEDES', 'SSANG_YONG']

# %%
for b in brand_in_test:   # или brand_in_test
    parse_data_02(99,'out211120',b)
    time.sleep(random.random()*10)
# Out:
# 2021-11-21 19:19:15.070 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-21 19:19:15.071 | INFO     | __main__:parse_data_02:21 - processing page: 1 BMW) # 1
# 2021-11-21 19:19:15.950 | INFO     | __main__:parse_data_02:21 - processing page: 2 BMW) # 1
# 2021-11-21 19:19:17.115 | INFO     | __main__:parse_data_02:21 - processing page: 3 BMW) # 1
# 2021-11-21 19:19:18.138 | INFO     | __main__:parse_data_02:21 - processing page: 4 BMW) # 1
# 2021-11-21 19:19:19.140 | INFO     | __main__:parse_data_02:21 - processing page: 5 BMW) # 1
# 2021-11-21 19:19:20.395 | INFO     | __main__:parse_data_02:21 - processing page: 6 BMW) # 1
# 2021-11-21 19:19:21.451 | INFO     | __main__:parse_data_02:21 - processing page: 7 BMW) # 1
# 2021-11-21 19:19:22.179 | INFO     | __main__:parse_data_02:21 - processing page: 8 BMW) # 1
# 2021-11-21 19:19:23.018 | INFO     | __main__:parse_data_02:21 - processing page: 9 BMW) # 1
# 2021-11-21 19:19:24.280 | INFO     | __main__:parse_data_02:21 - processing page: 10 BMW) # 1
# 2021-11-21 19:19:25.087 | INFO     | __main__:parse_data_02:21 - processing page: 11 BMW) # 1
# 2021-11-21 19:19:26.451 | INFO     | __main__:parse_data_02:21 - processing page: 12 BMW) # 1
# 2021-11-21 19:19:28.258 | INFO     | __main__:parse_data_02:21 - processing page: 13 BMW) # 1
# 2021-11-21 19:19:29.294 | INFO     | __main__:parse_data_02:21 - processing page: 14 BMW) # 1
# 2021-11-21 19:19:30.898 | INFO     | __main__:parse_data_02:21 - processing page: 15 BMW) # 1
# 2021-11-21 19:19:32.331 | INFO     | __main__:parse_data_02:21 - processing page: 16 BMW) # 1
# 2021-11-21 19:19:33.315 | INFO     | __main__:parse_data_02:21 - processing page: 17 BMW) # 1
# 2021-11-21 19:19:34.154 | INFO     | __main__:parse_data_02:21 - processing page: 18 BMW) # 1
# 2021-11-21 19:19:36.363 | INFO     | __main__:parse_data_02:21 - processing page: 19 BMW) # 1
# 2021-11-21 19:19:37.287 | INFO     | __main__:parse_data_02:21 - processing page: 20 BMW) # 1
# 2021-11-21 19:19:38.103 | INFO     | __main__:parse_data_02:21 - processing page: 21 BMW) # 1
# 2021-11-21 19:20:53.664 | INFO     | __main__:parse_data_02:21 - processing page: 79 BMW) # 1
# 2021-11-21 19:20:55.672 | INFO     | __main__:parse_data_02:21 - processing page: 80 BMW) # 1
# 2021-11-21 19:20:56.854 | INFO     | __main__:parse_data_02:21 - processing page: 81 BMW) # 1
# 2021-11-21 19:20:58.068 | INFO     | __main__:parse_data_02:21 - processing page: 82 BMW) # 1
# 2021-11-21 19:20:58.984 | INFO     | __main__:parse_data_02:21 - processing page: 83 BMW) # 1
# 2021-11-21 19:21:01.455 | INFO     | __main__:parse_data_02:21 - processing page: 84 BMW) # 1
# 2021-11-21 19:21:03.137 | INFO     | __main__:parse_data_02:21 - processing page: 85 BMW) # 1
# 2021-11-21 19:21:05.419 | INFO     | __main__:parse_data_02:21 - processing page: 86 BMW) # 1
# 2021-11-21 19:21:06.455 | INFO     | __main__:parse_data_02:21 - processing page: 87 BMW) # 1
# 2021-11-21 19:21:07.550 | INFO     | __main__:parse_data_02:21 - processing page: 88 BMW) # 1
# 2021-11-21 19:21:08.513 | INFO     | __main__:parse_data_02:21 - processing page: 89 BMW) # 1
# 2021-11-21 19:21:09.370 | INFO     | __main__:parse_data_02:21 - processing page: 90 BMW) # 1
# 2021-11-21 19:21:10.375 | INFO     | __main__:parse_data_02:21 - processing page: 91 BMW) # 1
# 2021-11-21 19:21:11.514 | INFO     | __main__:parse_data_02:21 - processing page: 92 BMW) # 1
# 2021-11-21 19:21:12.627 | INFO     | __main__:parse_data_02:21 - processing page: 93 BMW) # 1
# 2021-11-21 19:21:13.719 | INFO     | __main__:parse_data_02:21 - processing page: 94 BMW) # 1
# 2021-11-21 19:21:14.870 | INFO     | __main__:parse_data_02:21 - processing page: 95 BMW) # 1
# 2021-11-21 19:21:15.727 | INFO     | __main__:parse_data_02:21 - processing page: 96 BMW) # 1
# 2021-11-21 19:21:16.677 | INFO     | __main__:parse_data_02:21 - processing page: 97 BMW) # 1
# 2021-11-21 19:21:18.012 | INFO     | __main__:parse_data_02:21 - processing page: 98 BMW) # 1
# 2021-11-21 19:21:19.044 | INFO     | __main__:parse_data_02:21 - processing page: 99 BMW) # 1
# 2021-11-21 19:21:19.984 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1813 записей
# 2021-11-21 19:21:20.492 | INFO     | __main__:parse_data_02:43 - parsing successfully finished
# 2021-11-21 19:21:23.422 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-21 19:21:23.424 | INFO     | __main__:parse_data_02:21 - processing page: 1 VOLKSWAGEN) # 1
# 2021-11-21 19:21:24.404 | INFO     | __main__:parse_data_02:21 - processing page: 2 VOLKSWAGEN) # 1
# 2021-11-21 19:21:25.608 | INFO     | __main__:parse_data_02:21 - processing page: 3 VOLKSWAGEN) # 1
# 2021-11-21 19:21:26.800 | INFO     | __main__:parse_data_02:21 - processing page: 4 VOLKSWAGEN) # 1
# 2021-11-21 19:21:28.801 | INFO     | __main__:parse_data_02:21 - processing page: 5 VOLKSWAGEN) # 1
# 2021-11-21 19:21:29.521 | INFO     | __main__:parse_data_02:21 - processing page: 6 VOLKSWAGEN) # 1
# 2021-11-21 19:21:30.664 | INFO     | __main__:parse_data_02:21 - processing page: 7 VOLKSWAGEN) # 1
# 2021-11-21 19:21:31.539 | INFO     | __main__:parse_data_02:21 - processing page: 8 VOLKSWAGEN) # 1
# 2021-11-21 19:21:32.584 | INFO     | __main__:parse_data_02:21 - processing page: 9 VOLKSWAGEN) # 1
# 2021-11-21 19:21:33.593 | INFO     | __main__:parse_data_02:21 - processing page: 10 VOLKSWAGEN) # 1
# 2021-11-21 19:21:35.125 | INFO     | __main__:parse_data_02:21 - processing page: 11 VOLKSWAGEN) # 1
# 2021-11-21 19:21:36.040 | INFO     | __main__:parse_data_02:21 - processing page: 12 VOLKSWAGEN) # 1
# 2021-11-21 19:21:36.980 | INFO     | __main__:parse_data_02:21 - processing page: 13 VOLKSWAGEN) # 1
# 2021-11-21 19:21:37.898 | INFO     | __main__:parse_data_02:21 - processing page: 14 VOLKSWAGEN) # 1
# 2021-11-21 19:21:40.656 | INFO     | __main__:parse_data_02:21 - processing page: 15 VOLKSWAGEN) # 1
# 2021-11-21 19:21:41.573 | INFO     | __main__:parse_data_02:21 - processing page: 16 VOLKSWAGEN) # 1
# 2021-11-21 19:21:42.422 | INFO     | __main__:parse_data_02:21 - processing page: 17 VOLKSWAGEN) # 1
# 2021-11-21 19:21:43.496 | INFO     | __main__:parse_data_02:21 - processing page: 18 VOLKSWAGEN) # 1
# 2021-11-21 19:21:44.478 | INFO     | __main__:parse_data_02:21 - processing page: 19 VOLKSWAGEN) # 1
# 2021-11-21 19:21:45.585 | INFO     | __main__:parse_data_02:21 - processing page: 20 VOLKSWAGEN) # 1
# 2021-11-21 19:21:46.384 | INFO     | __main__:parse_data_02:21 - processing page: 21 VOLKSWAGEN) # 1
# 2021-11-21 19:21:47.191 | INFO     | __main__:parse_data_02:21 - processing page: 22 VOLKSWAGEN) # 1
# 2021-11-21 19:21:47.987 | INFO     | __main__:parse_data_02:21 - processing page: 23 VOLKSWAGEN) # 1
# 2021-11-21 19:21:48.864 | INFO     | __main__:parse_data_02:21 - processing page: 24 VOLKSWAGEN) # 1
# 2021-11-21 19:21:49.941 | INFO     | __main__:parse_data_02:21 - processing page: 25 VOLKSWAGEN) # 1
# 2021-11-21 19:21:50.867 | INFO     | __main__:parse_data_02:21 - processing page: 26 VOLKSWAGEN) # 1
# 2021-11-21 19:21:52.845 | INFO     | __main__:parse_data_02:21 - processing page: 27 VOLKSWAGEN) # 1
# 2021-11-21 19:21:53.806 | INFO     | __main__:parse_data_02:21 - processing page: 28 VOLKSWAGEN) # 1
# 2021-11-21 19:21:55.148 | INFO     | __main__:parse_data_02:21 - processing page: 29 VOLKSWAGEN) # 1
# 2021-11-21 19:21:56.143 | INFO     | __main__:parse_data_02:21 - processing page: 30 VOLKSWAGEN) # 1
# 2021-11-21 19:21:57.163 | INFO     | __main__:parse_data_02:21 - processing page: 31 VOLKSWAGEN) # 1
# 2021-11-21 19:21:58.061 | INFO     | __main__:parse_data_02:21 - processing page: 32 VOLKSWAGEN) # 1
# 2021-11-21 19:21:59.061 | INFO     | __main__:parse_data_02:21 - processing page: 33 VOLKSWAGEN) # 1
# 2021-11-21 19:22:00.010 | INFO     | __main__:parse_data_02:21 - processing page: 34 VOLKSWAGEN) # 1
# 2021-11-21 19:22:00.843 | INFO     | __main__:parse_data_02:21 - processing page: 35 VOLKSWAGEN) # 1
# 2021-11-21 19:22:01.670 | INFO     | __main__:parse_data_02:21 - processing page: 36 VOLKSWAGEN) # 1
# 2021-11-21 19:22:02.475 | INFO     | __main__:parse_data_02:21 - processing page: 37 VOLKSWAGEN) # 1
# 2021-11-21 19:22:03.312 | INFO     | __main__:parse_data_02:21 - processing page: 38 VOLKSWAGEN) # 1
# 2021-11-21 19:22:04.146 | INFO     | __main__:parse_data_02:21 - processing page: 39 VOLKSWAGEN) # 1
# 2021-11-21 19:22:04.970 | INFO     | __main__:parse_data_02:21 - processing page: 40 VOLKSWAGEN) # 1
# 2021-11-21 19:22:06.093 | INFO     | __main__:parse_data_02:21 - processing page: 41 VOLKSWAGEN) # 1
# 2021-11-21 19:22:07.263 | INFO     | __main__:parse_data_02:21 - processing page: 42 VOLKSWAGEN) # 1
# 2021-11-21 19:22:08.233 | INFO     | __main__:parse_data_02:21 - processing page: 43 VOLKSWAGEN) # 1
# 2021-11-21 19:22:09.041 | INFO     | __main__:parse_data_02:21 - processing page: 44 VOLKSWAGEN) # 1
# 2021-11-21 19:22:09.750 | INFO     | __main__:parse_data_02:21 - processing page: 45 VOLKSWAGEN) # 1
# 2021-11-21 19:22:10.901 | INFO     | __main__:parse_data_02:21 - processing page: 46 VOLKSWAGEN) # 1
# 2021-11-21 19:22:12.007 | INFO     | __main__:parse_data_02:21 - processing page: 47 VOLKSWAGEN) # 1
# 2021-11-21 19:22:12.686 | INFO     | __main__:parse_data_02:21 - processing page: 48 VOLKSWAGEN) # 1
# 2021-11-21 19:22:13.377 | INFO     | __main__:parse_data_02:21 - processing page: 49 VOLKSWAGEN) # 1
# 2021-11-21 19:22:14.346 | INFO     | __main__:parse_data_02:21 - processing page: 50 VOLKSWAGEN) # 1
# 2021-11-21 19:22:15.080 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1850 записей
# 2021-11-21 19:22:15.486 | INFO     | __main__:parse_data_02:21 - processing page: 51 VOLKSWAGEN) # 1
# 2021-11-21 19:22:16.058 | INFO     | __main__:parse_data_02:21 - processing page: 52 VOLKSWAGEN) # 1
# 2021-11-21 19:22:16.842 | INFO     | __main__:parse_data_02:21 - processing page: 53 VOLKSWAGEN) # 1
# 2021-11-21 19:22:17.634 | INFO     | __main__:parse_data_02:21 - processing page: 54 VOLKSWAGEN) # 1
# 2021-11-21 19:22:18.362 | INFO     | __main__:parse_data_02:21 - processing page: 55 VOLKSWAGEN) # 1
# 2021-11-21 19:22:19.334 | INFO     | __main__:parse_data_02:21 - processing page: 56 VOLKSWAGEN) # 1
# 2021-11-21 19:22:20.165 | INFO     | __main__:parse_data_02:21 - processing page: 57 VOLKSWAGEN) # 1
# 2021-11-21 19:22:20.992 | INFO     | __main__:parse_data_02:21 - processing page: 58 VOLKSWAGEN) # 1
# 2021-11-21 19:22:21.762 | INFO     | __main__:parse_data_02:21 - processing page: 59 VOLKSWAGEN) # 1
# 2021-11-21 19:22:22.774 | INFO     | __main__:parse_data_02:21 - processing page: 60 VOLKSWAGEN) # 1
# 2021-11-21 19:22:23.621 | INFO     | __main__:parse_data_02:21 - processing page: 61 VOLKSWAGEN) # 1
# 2021-11-21 19:22:24.480 | INFO     | __main__:parse_data_02:21 - processing page: 62 VOLKSWAGEN) # 1
# 2021-11-21 19:22:25.252 | INFO     | __main__:parse_data_02:21 - processing page: 63 VOLKSWAGEN) # 1
# 2021-11-21 19:22:26.041 | INFO     | __main__:parse_data_02:21 - processing page: 64 VOLKSWAGEN) # 1
# 2021-11-21 19:22:26.875 | INFO     | __main__:parse_data_02:21 - processing page: 65 VOLKSWAGEN) # 1
# 2021-11-21 19:22:27.718 | INFO     | __main__:parse_data_02:21 - processing page: 66 VOLKSWAGEN) # 1
# 2021-11-21 19:22:28.382 | INFO     | __main__:parse_data_02:21 - processing page: 67 VOLKSWAGEN) # 1
# 2021-11-21 19:22:29.365 | INFO     | __main__:parse_data_02:21 - processing page: 68 VOLKSWAGEN) # 1
# 2021-11-21 19:22:30.219 | INFO     | __main__:parse_data_02:21 - processing page: 69 VOLKSWAGEN) # 1
# 2021-11-21 19:22:31.212 | INFO     | __main__:parse_data_02:21 - processing page: 70 VOLKSWAGEN) # 1
# 2021-11-21 19:22:31.842 | INFO     | __main__:parse_data_02:21 - processing page: 71 VOLKSWAGEN) # 1
# 2021-11-21 19:22:32.693 | INFO     | __main__:parse_data_02:21 - processing page: 72 VOLKSWAGEN) # 1
# 2021-11-21 19:22:33.526 | INFO     | __main__:parse_data_02:21 - processing page: 73 VOLKSWAGEN) # 1
# 2021-11-21 19:22:34.551 | INFO     | __main__:parse_data_02:21 - processing page: 74 VOLKSWAGEN) # 1
# 2021-11-21 19:22:35.202 | INFO     | __main__:parse_data_02:21 - processing page: 75 VOLKSWAGEN) # 1
# 2021-11-21 19:22:35.954 | INFO     | __main__:parse_data_02:21 - processing page: 76 VOLKSWAGEN) # 1
# 2021-11-21 19:22:37.060 | INFO     | __main__:parse_data_02:21 - processing page: 77 VOLKSWAGEN) # 1
# 2021-11-21 19:22:37.934 | INFO     | __main__:parse_data_02:21 - processing page: 78 VOLKSWAGEN) # 1
# 2021-11-21 19:22:38.645 | INFO     | __main__:parse_data_02:21 - processing page: 79 VOLKSWAGEN) # 1
# 2021-11-21 19:22:39.571 | INFO     | __main__:parse_data_02:21 - processing page: 80 VOLKSWAGEN) # 1
# 2021-11-21 19:22:40.509 | INFO     | __main__:parse_data_02:21 - processing page: 81 VOLKSWAGEN) # 1
# 2021-11-21 19:22:41.183 | INFO     | __main__:parse_data_02:21 - processing page: 82 VOLKSWAGEN) # 1
# 2021-11-21 19:22:41.999 | INFO     | __main__:parse_data_02:21 - processing page: 83 VOLKSWAGEN) # 1
# 2021-11-21 19:22:42.802 | INFO     | __main__:parse_data_02:21 - processing page: 84 VOLKSWAGEN) # 1
# 2021-11-21 19:22:43.603 | INFO     | __main__:parse_data_02:21 - processing page: 85 VOLKSWAGEN) # 1
# 2021-11-21 19:22:44.350 | INFO     | __main__:parse_data_02:21 - processing page: 86 VOLKSWAGEN) # 1
# 2021-11-21 19:22:44.968 | INFO     | __main__:parse_data_02:21 - processing page: 87 VOLKSWAGEN) # 1
# 2021-11-21 19:22:45.684 | INFO     | __main__:parse_data_02:21 - processing page: 88 VOLKSWAGEN) # 1
# 2021-11-21 19:22:46.401 | INFO     | __main__:parse_data_02:21 - processing page: 89 VOLKSWAGEN) # 1
# 2021-11-21 19:22:47.230 | INFO     | __main__:parse_data_02:21 - processing page: 90 VOLKSWAGEN) # 1
# 2021-11-21 19:22:47.997 | INFO     | __main__:parse_data_02:21 - processing page: 91 VOLKSWAGEN) # 1
# 2021-11-21 19:22:48.718 | INFO     | __main__:parse_data_02:21 - processing page: 92 VOLKSWAGEN) # 1
# 2021-11-21 19:22:49.761 | INFO     | __main__:parse_data_02:21 - processing page: 93 VOLKSWAGEN) # 1
# 2021-11-21 19:22:50.741 | INFO     | __main__:parse_data_02:21 - processing page: 94 VOLKSWAGEN) # 1
# 2021-11-21 19:22:51.895 | INFO     | __main__:parse_data_02:21 - processing page: 95 VOLKSWAGEN) # 1
# 2021-11-21 19:22:52.874 | INFO     | __main__:parse_data_02:21 - processing page: 96 VOLKSWAGEN) # 1
# 2021-11-21 19:22:53.745 | INFO     | __main__:parse_data_02:21 - processing page: 97 VOLKSWAGEN) # 1
# 2021-11-21 19:22:54.660 | INFO     | __main__:parse_data_02:21 - processing page: 98 VOLKSWAGEN) # 1
# 2021-11-21 19:22:55.338 | INFO     | __main__:parse_data_02:21 - processing page: 99 VOLKSWAGEN) # 1
# 2021-11-21 19:22:56.162 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1813 записей
# 2021-11-21 19:22:56.534 | INFO     | __main__:parse_data_02:43 - parsing successfully finished
# 2021-11-21 19:22:56.986 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-21 19:22:56.987 | INFO     | __main__:parse_data_02:21 - processing page: 1 NISSAN) # 1
# 2021-11-21 19:22:57.673 | INFO     | __main__:parse_data_02:21 - processing page: 2 NISSAN) # 1
# 2021-11-21 19:22:58.390 | INFO     | __main__:parse_data_02:21 - processing page: 3 NISSAN) # 1
# 2021-11-21 19:22:59.213 | INFO     | __main__:parse_data_02:21 - processing page: 4 NISSAN) # 1
# 2021-11-21 19:22:59.816 | INFO     | __main__:parse_data_02:21 - processing page: 5 NISSAN) # 1
# 2021-11-21 19:23:00.872 | INFO     | __main__:parse_data_02:21 - processing page: 6 NISSAN) # 1
# 2021-11-21 19:23:01.945 | INFO     | __main__:parse_data_02:21 - processing page: 7 NISSAN) # 1
# 2021-11-21 19:23:03.820 | INFO     | __main__:parse_data_02:21 - processing page: 8 NISSAN) # 1
# 2021-11-21 19:23:04.840 | INFO     | __main__:parse_data_02:21 - processing page: 9 NISSAN) # 1
# 2021-11-21 19:23:05.654 | INFO     | __main__:parse_data_02:21 - processing page: 10 NISSAN) # 1
# 2021-11-21 19:23:06.347 | INFO     | __main__:parse_data_02:21 - processing page: 11 NISSAN) # 1
# 2021-11-21 19:23:06.947 | INFO     | __main__:parse_data_02:21 - processing page: 12 NISSAN) # 1
# 2021-11-21 19:23:08.090 | INFO     | __main__:parse_data_02:21 - processing page: 13 NISSAN) # 1
# 2021-11-21 19:23:09.190 | INFO     | __main__:parse_data_02:21 - processing page: 14 NISSAN) # 1
# 2021-11-21 19:23:09.831 | INFO     | __main__:parse_data_02:21 - processing page: 15 NISSAN) # 1
# 2021-11-21 19:23:10.431 | INFO     | __main__:parse_data_02:21 - processing page: 16 NISSAN) # 1
# 2021-11-21 19:23:11.296 | INFO     | __main__:parse_data_02:21 - processing page: 17 NISSAN) # 1
# 2021-11-21 19:23:12.218 | INFO     | __main__:parse_data_02:21 - processing page: 18 NISSAN) # 1
# 2021-11-21 19:23:12.988 | INFO     | __main__:parse_data_02:21 - processing page: 19 NISSAN) # 1
# 2021-11-21 19:23:13.879 | INFO     | __main__:parse_data_02:21 - processing page: 20 NISSAN) # 1
# 2021-11-21 19:23:14.932 | INFO     | __main__:parse_data_02:21 - processing page: 21 NISSAN) # 1
# 2021-11-21 19:23:16.280 | INFO     | __main__:parse_data_02:21 - processing page: 22 NISSAN) # 1
# 2021-11-21 19:23:17.042 | INFO     | __main__:parse_data_02:21 - processing page: 23 NISSAN) # 1
# 2021-11-21 19:23:17.842 | INFO     | __main__:parse_data_02:21 - processing page: 24 NISSAN) # 1
# 2021-11-21 19:23:18.940 | INFO     | __main__:parse_data_02:21 - processing page: 25 NISSAN) # 1
# 2021-11-21 19:23:20.184 | INFO     | __main__:parse_data_02:21 - processing page: 26 NISSAN) # 1
# 2021-11-21 19:23:21.209 | INFO     | __main__:parse_data_02:21 - processing page: 27 NISSAN) # 1
# 2021-11-21 19:23:22.218 | INFO     | __main__:parse_data_02:21 - processing page: 28 NISSAN) # 1
# 2021-11-21 19:23:23.150 | INFO     | __main__:parse_data_02:21 - processing page: 29 NISSAN) # 1
# 2021-11-21 19:23:23.934 | INFO     | __main__:parse_data_02:21 - processing page: 30 NISSAN) # 1
# 2021-11-21 19:23:24.892 | INFO     | __main__:parse_data_02:21 - processing page: 31 NISSAN) # 1
# 2021-11-21 19:23:26.019 | INFO     | __main__:parse_data_02:21 - processing page: 32 NISSAN) # 1
# 2021-11-21 19:23:27.107 | INFO     | __main__:parse_data_02:21 - processing page: 33 NISSAN) # 1
# 2021-11-21 19:23:28.180 | INFO     | __main__:parse_data_02:21 - processing page: 34 NISSAN) # 1
# 2021-11-21 19:23:29.074 | INFO     | __main__:parse_data_02:21 - processing page: 35 NISSAN) # 1
# 2021-11-21 19:23:30.255 | INFO     | __main__:parse_data_02:21 - processing page: 36 NISSAN) # 1
# 2021-11-21 19:23:32.308 | INFO     | __main__:parse_data_02:21 - processing page: 37 NISSAN) # 1
# 2021-11-21 19:23:34.243 | INFO     | __main__:parse_data_02:21 - processing page: 38 NISSAN) # 1
# 2021-11-21 19:23:35.494 | INFO     | __main__:parse_data_02:21 - processing page: 39 NISSAN) # 1
# 2021-11-21 19:23:36.852 | INFO     | __main__:parse_data_02:21 - processing page: 40 NISSAN) # 1
# 2021-11-21 19:23:37.881 | INFO     | __main__:parse_data_02:21 - processing page: 41 NISSAN) # 1
# 2021-11-21 19:23:38.812 | INFO     | __main__:parse_data_02:21 - processing page: 42 NISSAN) # 1
# 2021-11-21 19:23:39.959 | INFO     | __main__:parse_data_02:21 - processing page: 43 NISSAN) # 1
# 2021-11-21 19:23:41.214 | INFO     | __main__:parse_data_02:21 - processing page: 44 NISSAN) # 1
# 2021-11-21 19:23:42.313 | INFO     | __main__:parse_data_02:21 - processing page: 45 NISSAN) # 1
# 2021-11-21 19:23:43.345 | INFO     | __main__:parse_data_02:21 - processing page: 46 NISSAN) # 1
# 2021-11-21 19:23:44.603 | INFO     | __main__:parse_data_02:21 - processing page: 47 NISSAN) # 1
# 2021-11-21 19:23:45.316 | INFO     | __main__:parse_data_02:21 - processing page: 48 NISSAN) # 1
# 2021-11-21 19:23:46.434 | INFO     | __main__:parse_data_02:21 - processing page: 49 NISSAN) # 1
# 2021-11-21 19:23:47.240 | INFO     | __main__:parse_data_02:21 - processing page: 50 NISSAN) # 1
# 2021-11-21 19:23:48.365 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1813 записей
# 2021-11-21 19:23:48.726 | INFO     | __main__:parse_data_02:21 - processing page: 51 NISSAN) # 1
# 2021-11-21 19:23:49.589 | INFO     | __main__:parse_data_02:21 - processing page: 52 NISSAN) # 1
# 2021-11-21 19:23:50.467 | INFO     | __main__:parse_data_02:21 - processing page: 53 NISSAN) # 1
# 2021-11-21 19:23:51.588 | INFO     | __main__:parse_data_02:21 - processing page: 54 NISSAN) # 1
# 2021-11-21 19:23:52.427 | INFO     | __main__:parse_data_02:21 - processing page: 55 NISSAN) # 1
# 2021-11-21 19:23:53.446 | INFO     | __main__:parse_data_02:21 - processing page: 56 NISSAN) # 1
# 2021-11-21 19:23:54.094 | INFO     | __main__:parse_data_02:21 - processing page: 57 NISSAN) # 1
# 2021-11-21 19:23:55.184 | INFO     | __main__:parse_data_02:21 - processing page: 58 NISSAN) # 1
# 2021-11-21 19:23:55.969 | INFO     | __main__:parse_data_02:21 - processing page: 59 NISSAN) # 1
# 2021-11-21 19:23:56.773 | INFO     | __main__:parse_data_02:21 - processing page: 60 NISSAN) # 1
# 2021-11-21 19:23:57.548 | INFO     | __main__:parse_data_02:21 - processing page: 61 NISSAN) # 1
# 2021-11-21 19:26:25.971 | INFO     | __main__:parse_data_02:21 - processing page: 98 MERCEDES) # 1
# 2021-11-21 19:26:26.855 | INFO     | __main__:parse_data_02:21 - processing page: 99 MERCEDES) # 1
# 2021-11-21 19:26:29.029 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1813 записей
# 2021-11-21 19:26:29.539 | INFO     | __main__:parse_data_02:43 - parsing successfully finished
# 2021-11-21 19:26:34.639 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-21 19:26:34.640 | INFO     | __main__:parse_data_02:21 - processing page: 1 TOYOTA) # 1
# 2021-11-21 19:26:35.740 | INFO     | __main__:parse_data_02:21 - processing page: 2 TOYOTA) # 1
# 2021-11-21 19:26:36.651 | INFO     | __main__:parse_data_02:21 - processing page: 3 TOYOTA) # 1
# 2021-11-21 19:26:38.115 | INFO     | __main__:parse_data_02:21 - processing page: 4 TOYOTA) # 1
# 2021-11-21 19:26:39.493 | INFO     | __main__:parse_data_02:21 - processing page: 5 TOYOTA) # 1
# 2021-11-21 19:26:41.049 | INFO     | __main__:parse_data_02:21 - processing page: 6 TOYOTA) # 1
# 2021-11-21 19:26:42.156 | INFO     | __main__:parse_data_02:21 - processing page: 7 TOYOTA) # 1
# 2021-11-21 19:26:43.021 | INFO     | __main__:parse_data_02:21 - processing page: 8 TOYOTA) # 1
# 2021-11-21 19:26:43.974 | INFO     | __main__:parse_data_02:21 - processing page: 9 TOYOTA) # 1
# 2021-11-21 19:26:44.897 | INFO     | __main__:parse_data_02:21 - processing page: 10 TOYOTA) # 1
# 2021-11-21 19:26:45.967 | INFO     | __main__:parse_data_02:21 - processing page: 11 TOYOTA) # 1
# 2021-11-21 19:26:46.855 | INFO     | __main__:parse_data_02:21 - processing page: 12 TOYOTA) # 1
# 2021-11-21 19:26:47.637 | INFO     | __main__:parse_data_02:21 - processing page: 13 TOYOTA) # 1
# 2021-11-21 19:26:48.792 | INFO     | __main__:parse_data_02:21 - processing page: 14 TOYOTA) # 1
# 2021-11-21 19:26:49.789 | INFO     | __main__:parse_data_02:21 - processing page: 15 TOYOTA) # 1
# 2021-11-21 19:26:50.984 | INFO     | __main__:parse_data_02:21 - processing page: 16 TOYOTA) # 1
# 2021-11-21 19:26:52.050 | INFO     | __main__:parse_data_02:21 - processing page: 17 TOYOTA) # 1
# 2021-11-21 19:26:53.612 | INFO     | __main__:parse_data_02:21 - processing page: 18 TOYOTA) # 1
# 2021-11-21 19:26:54.599 | INFO     | __main__:parse_data_02:21 - processing page: 19 TOYOTA) # 1
# 2021-11-21 19:26:56.025 | INFO     | __main__:parse_data_02:21 - processing page: 20 TOYOTA) # 1
# 2021-11-21 19:26:57.299 | INFO     | __main__:parse_data_02:21 - processing page: 21 TOYOTA) # 1
# 2021-11-21 19:26:58.391 | INFO     | __main__:parse_data_02:21 - processing page: 22 TOYOTA) # 1
# 2021-11-21 19:26:59.550 | INFO     | __main__:parse_data_02:21 - processing page: 23 TOYOTA) # 1
# 2021-11-21 19:27:00.639 | INFO     | __main__:parse_data_02:21 - processing page: 24 TOYOTA) # 1
# 2021-11-21 19:27:01.633 | INFO     | __main__:parse_data_02:21 - processing page: 25 TOYOTA) # 1
# 2021-11-21 19:27:02.689 | INFO     | __main__:parse_data_02:21 - processing page: 26 TOYOTA) # 1
# 2021-11-21 19:27:03.469 | INFO     | __main__:parse_data_02:21 - processing page: 27 TOYOTA) # 1
# 2021-11-21 19:27:05.120 | INFO     | __main__:parse_data_02:21 - processing page: 28 TOYOTA) # 1
# 2021-11-21 19:27:06.103 | INFO     | __main__:parse_data_02:21 - processing page: 29 TOYOTA) # 1
# 2021-11-21 19:27:07.373 | INFO     | __main__:parse_data_02:21 - processing page: 30 TOYOTA) # 1
# 2021-11-21 19:27:08.635 | INFO     | __main__:parse_data_02:21 - processing page: 31 TOYOTA) # 1
# 2021-11-21 19:27:09.651 | INFO     | __main__:parse_data_02:21 - processing page: 32 TOYOTA) # 1
# 2021-11-21 19:27:10.597 | INFO     | __main__:parse_data_02:21 - processing page: 33 TOYOTA) # 1
# 2021-11-21 19:27:12.517 | INFO     | __main__:parse_data_02:21 - processing page: 34 TOYOTA) # 1
# 2021-11-21 19:27:13.709 | INFO     | __main__:parse_data_02:21 - processing page: 35 TOYOTA) # 1
# 2021-11-21 19:27:15.761 | INFO     | __main__:parse_data_02:21 - processing page: 36 TOYOTA) # 1
# 2021-11-21 19:27:16.901 | INFO     | __main__:parse_data_02:21 - processing page: 37 TOYOTA) # 1
# 2021-11-21 19:27:17.866 | INFO     | __main__:parse_data_02:21 - processing page: 38 TOYOTA) # 1
# 2021-11-21 19:27:19.190 | INFO     | __main__:parse_data_02:21 - processing page: 39 TOYOTA) # 1
# 2021-11-21 19:27:20.134 | INFO     | __main__:parse_data_02:21 - processing page: 40 TOYOTA) # 1
# 2021-11-21 19:27:21.146 | INFO     | __main__:parse_data_02:21 - processing page: 41 TOYOTA) # 1
# 2021-11-21 19:27:22.277 | INFO     | __main__:parse_data_02:21 - processing page: 42 TOYOTA) # 1
# 2021-11-21 19:27:23.305 | INFO     | __main__:parse_data_02:21 - processing page: 43 TOYOTA) # 1
# 2021-11-21 19:27:24.347 | INFO     | __main__:parse_data_02:21 - processing page: 44 TOYOTA) # 1
# 2021-11-21 19:27:25.169 | INFO     | __main__:parse_data_02:21 - processing page: 45 TOYOTA) # 1
# 2021-11-21 19:27:25.938 | INFO     | __main__:parse_data_02:21 - processing page: 46 TOYOTA) # 1
# 2021-11-21 19:27:27.237 | INFO     | __main__:parse_data_02:21 - processing page: 47 TOYOTA) # 1
# 2021-11-21 19:27:28.060 | INFO     | __main__:parse_data_02:21 - processing page: 48 TOYOTA) # 1
# 2021-11-21 19:27:29.264 | INFO     | __main__:parse_data_02:21 - processing page: 49 TOYOTA) # 1
# 2021-11-21 19:27:30.318 | INFO     | __main__:parse_data_02:21 - processing page: 50 TOYOTA) # 1
# 2021-11-21 19:27:31.186 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1850 записей
# 2021-11-21 19:27:31.641 | INFO     | __main__:parse_data_02:21 - processing page: 51 TOYOTA) # 1
# 2021-11-21 19:27:32.596 | INFO     | __main__:parse_data_02:21 - processing page: 52 TOYOTA) # 1
# 2021-11-21 19:27:33.739 | INFO     | __main__:parse_data_02:21 - processing page: 53 TOYOTA) # 1
# 2021-11-21 19:27:34.573 | INFO     | __main__:parse_data_02:21 - processing page: 54 TOYOTA) # 1
# 2021-11-21 19:27:36.489 | INFO     | __main__:parse_data_02:21 - processing page: 55 TOYOTA) # 1
# 2021-11-21 19:27:37.821 | INFO     | __main__:parse_data_02:21 - processing page: 56 TOYOTA) # 1
# 2021-11-21 19:27:38.546 | INFO     | __main__:parse_data_02:21 - processing page: 57 TOYOTA) # 1
# 2021-11-21 19:27:39.438 | INFO     | __main__:parse_data_02:21 - processing page: 58 TOYOTA) # 1
# 2021-11-21 19:27:40.492 | INFO     | __main__:parse_data_02:21 - processing page: 59 TOYOTA) # 1
# 2021-11-21 19:27:41.436 | INFO     | __main__:parse_data_02:21 - processing page: 60 TOYOTA) # 1
# 2021-11-21 19:27:42.550 | INFO     | __main__:parse_data_02:21 - processing page: 61 TOYOTA) # 1
# 2021-11-21 19:27:43.794 | INFO     | __main__:parse_data_02:21 - processing page: 62 TOYOTA) # 1
# 2021-11-21 19:27:45.575 | INFO     | __main__:parse_data_02:21 - processing page: 63 TOYOTA) # 1
# 2021-11-21 19:27:46.852 | INFO     | __main__:parse_data_02:21 - processing page: 64 TOYOTA) # 1
# 2021-11-21 19:27:47.832 | INFO     | __main__:parse_data_02:21 - processing page: 65 TOYOTA) # 1
# 2021-11-21 19:27:48.668 | INFO     | __main__:parse_data_02:21 - processing page: 66 TOYOTA) # 1
# 2021-11-21 19:27:49.662 | INFO     | __main__:parse_data_02:21 - processing page: 67 TOYOTA) # 1
# 2021-11-21 19:27:50.846 | INFO     | __main__:parse_data_02:21 - processing page: 68 TOYOTA) # 1
# 2021-11-21 19:27:51.789 | INFO     | __main__:parse_data_02:21 - processing page: 69 TOYOTA) # 1
# 2021-11-21 19:27:52.657 | INFO     | __main__:parse_data_02:21 - processing page: 70 TOYOTA) # 1
# 2021-11-21 19:27:53.504 | INFO     | __main__:parse_data_02:21 - processing page: 71 TOYOTA) # 1
# 2021-11-21 19:27:54.583 | INFO     | __main__:parse_data_02:21 - processing page: 72 TOYOTA) # 1
# 2021-11-21 19:27:55.452 | INFO     | __main__:parse_data_02:21 - processing page: 73 TOYOTA) # 1
# 2021-11-21 19:27:56.260 | INFO     | __main__:parse_data_02:21 - processing page: 74 TOYOTA) # 1
# 2021-11-21 19:27:57.073 | INFO     | __main__:parse_data_02:21 - processing page: 75 TOYOTA) # 1
# 2021-11-21 19:27:57.908 | INFO     | __main__:parse_data_02:21 - processing page: 76 TOYOTA) # 1
# ...
# 2021-11-21 19:36:39.724 | INFO     | __main__:parse_data_02:21 - processing page: 41 INFINITI) # 1
# 2021-11-21 19:36:58.443 | INFO     | __main__:parse_data_02:21 - processing page: 97 INFINITI) # 1
# 2021-11-21 19:36:58.694 | INFO     | __main__:parse_data_02:21 - processing page: 98 INFINITI) # 1
# 2021-11-21 19:36:59.060 | INFO     | __main__:parse_data_02:21 - processing page: 99 INFINITI) # 1
# 2021-11-21 19:36:59.341 | INFO     | __main__:parse_data_02:43 - parsing successfully finished
# 2021-11-21 19:37:02.169 | INFO     | __main__:parse_data_02:5 - Starting parse data from auto.ru about cars
# 2021-11-21 19:37:02.170 | INFO     | __main__:parse_data_02:21 - processing page: 1 LEXUS) # 1
# 2021-11-21 19:37:02.966 | INFO     | __main__:parse_data_02:21 - processing page: 2 LEXUS) # 1
# 2021-11-21 19:37:03.912 | INFO     | __main__:parse_data_02:21 - processing page: 3 LEXUS) # 1
# 2021-11-21 19:37:04.843 | INFO     | __main__:parse_data_02:21 - processing page: 4 LEXUS) # 1
# 2021-11-21 19:37:05.860 | INFO     | __main__:parse_data_02:21 - processing page: 5 LEXUS) # 1
# 2021-11-21 19:37:06.717 | INFO     | __main__:parse_data_02:21 - processing page: 6 LEXUS) # 1
# 2021-11-21 19:37:07.824 | INFO     | __main__:parse_data_02:21 - processing page: 7 LEXUS) # 1
# 2021-11-21 19:37:08.877 | INFO     | __main__:parse_data_02:21 - processing page: 8 LEXUS) # 1
# 2021-11-21 19:37:09.962 | INFO     | __main__:parse_data_02:21 - processing page: 9 LEXUS) # 1
# 2021-11-21 19:37:11.129 | INFO     | __main__:parse_data_02:21 - processing page: 10 LEXUS) # 1
# 2021-11-21 19:37:11.922 | INFO     | __main__:parse_data_02:21 - processing page: 11 LEXUS) # 1
# 2021-11-21 19:37:12.928 | INFO     | __main__:parse_data_02:21 - processing page: 12 LEXUS) # 1
# 2021-11-21 19:37:13.843 | INFO     | __main__:parse_data_02:21 - processing page: 13 LEXUS) # 1
# 2021-11-21 19:37:15.055 | INFO     | __main__:parse_data_02:21 - processing page: 14 LEXUS) # 1
# 2021-11-21 19:37:16.395 | INFO     | __main__:parse_data_02:21 - processing page: 15 LEXUS) # 1
# 2021-11-21 19:37:17.491 | INFO     | __main__:parse_data_02:21 - processing page: 16 LEXUS) # 1
# 2021-11-21 19:37:18.244 | INFO     | __main__:parse_data_02:21 - processing page: 17 LEXUS) # 1
# 2021-11-21 19:37:19.228 | INFO     | __main__:parse_data_02:21 - processing page: 18 LEXUS) # 1
# 2021-11-21 19:37:19.963 | INFO     | __main__:parse_data_02:21 - processing page: 19 LEXUS) # 1
# 2021-11-21 19:37:20.704 | INFO     | __main__:parse_data_02:21 - processing page: 20 LEXUS) # 1
# 2021-11-21 19:37:21.714 | INFO     | __main__:parse_data_02:21 - processing page: 21 LEXUS) # 1
# 2021-11-21 19:37:22.891 | INFO     | __main__:parse_data_02:21 - processing page: 22 LEXUS) # 1
# 2021-11-21 19:37:23.976 | INFO     | __main__:parse_data_02:21 - processing page: 23 LEXUS) # 1
# 2021-11-21 19:37:24.913 | INFO     | __main__:parse_data_02:21 - processing page: 24 LEXUS) # 1
# 2021-11-21 19:37:25.993 | INFO     | __main__:parse_data_02:21 - processing page: 25 LEXUS) # 1
# 2021-11-21 19:37:26.642 | INFO     | __main__:parse_data_02:21 - processing page: 26 LEXUS) # 1
# 2021-11-21 19:37:27.471 | INFO     | __main__:parse_data_02:21 - processing page: 27 LEXUS) # 1
# 2021-11-21 19:37:28.214 | INFO     | __main__:parse_data_02:21 - processing page: 28 LEXUS) # 1
# 2021-11-21 19:37:29.257 | INFO     | __main__:parse_data_02:21 - processing page: 29 LEXUS) # 1
# 2021-11-21 19:37:30.343 | INFO     | __main__:parse_data_02:21 - processing page: 30 LEXUS) # 1
# 2021-11-21 19:37:31.546 | INFO     | __main__:parse_data_02:21 - processing page: 31 LEXUS) # 1
# 2021-11-21 19:37:32.779 | INFO     | __main__:parse_data_02:21 - processing page: 32 LEXUS) # 1
# 2021-11-21 19:37:33.926 | INFO     | __main__:parse_data_02:21 - processing page: 33 LEXUS) # 1
# 2021-11-21 19:37:34.889 | INFO     | __main__:parse_data_02:21 - processing page: 34 LEXUS) # 1
# 2021-11-21 19:37:35.739 | INFO     | __main__:parse_data_02:21 - processing page: 35 LEXUS) # 1
# 2021-11-21 19:37:36.707 | INFO     | __main__:parse_data_02:21 - processing page: 36 LEXUS) # 1
# 2021-11-21 19:37:37.705 | INFO     | __main__:parse_data_02:21 - processing page: 37 LEXUS) # 1
# 2021-11-21 19:37:38.492 | INFO     | __main__:parse_data_02:21 - processing page: 38 LEXUS) # 1
# 2021-11-21 19:37:39.520 | INFO     | __main__:parse_data_02:21 - processing page: 39 LEXUS) # 1
# 2021-11-21 19:37:40.284 | INFO     | __main__:parse_data_02:21 - processing page: 40 LEXUS) # 1
# 2021-11-21 19:37:40.973 | INFO     | __main__:parse_data_02:21 - processing page: 41 LEXUS) # 1
# 2021-11-21 19:37:41.963 | INFO     | __main__:parse_data_02:21 - processing page: 42 LEXUS) # 1
# 2021-11-21 19:37:42.498 | INFO     | __main__:parse_data_02:21 - processing page: 43 LEXUS) # 1
# 2021-11-21 19:37:43.219 | INFO     | __main__:parse_data_02:21 - processing page: 44 LEXUS) # 1
# 2021-11-21 19:37:44.076 | INFO     | __main__:parse_data_02:21 - processing page: 45 LEXUS) # 1
# 2021-11-21 19:37:44.834 | INFO     | __main__:parse_data_02:21 - processing page: 46 LEXUS) # 1
# 2021-11-21 19:37:45.782 | INFO     | __main__:parse_data_02:21 - processing page: 47 LEXUS) # 1
# 2021-11-21 19:37:46.640 | INFO     | __main__:parse_data_02:21 - processing page: 48 LEXUS) # 1
# 2021-11-21 19:37:47.529 | INFO     | __main__:parse_data_02:21 - processing page: 49 LEXUS) # 1
# 2021-11-21 19:37:48.493 | INFO     | __main__:parse_data_02:21 - processing page: 50 LEXUS) # 1
# 2021-11-21 19:37:49.496 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 1850 записей
# 2021-11-21 19:37:49.933 | INFO     | __main__:parse_data_02:21 - processing page: 51 LEXUS) # 1
# 2021-11-21 19:37:50.813 | INFO     | __main__:parse_data_02:21 - processing page: 52 LEXUS) # 1
# 2021-11-21 19:37:51.456 | INFO     | __main__:parse_data_02:21 - processing page: 53 LEXUS) # 1
# 2021-11-21 19:37:52.056 | INFO     | __main__:parse_data_02:21 - processing page: 54 LEXUS) # 1
# 2021-11-21 19:37:52.387 | INFO     | __main__:parse_data_02:21 - processing page: 55 LEXUS) # 1
# 2021-11-21 19:37:52.839 | INFO     | __main__:parse_data_02:21 - processing page: 56 LEXUS) # 1
# 2021-11-21 19:37:53.137 | INFO     | __main__:parse_data_02:21 - processing page: 57 LEXUS) # 1
# 2021-11-21 19:37:53.536 | INFO     | __main__:parse_data_02:21 - processing page: 58 LEXUS) # 1
# 2021-11-21 19:37:53.842 | INFO     | __main__:parse_data_02:21 - processing page: 59 LEXUS) # 1
# 2021-11-21 19:37:54.497 | INFO     | __main__:parse_data_02:21 - processing page: 60 LEXUS) # 1
# 2021-11-21 19:37:54.771 | INFO     | __main__:parse_data_02:21 - processing page: 61 LEXUS) # 1
# 2021-11-21 19:37:55.063 | INFO     | __main__:parse_data_02:21 - processing page: 62 LEXUS) # 1
# 2021-11-21 19:37:55.298 | INFO     | __main__:parse_data_02:21 - processing page: 63 LEXUS) # 1
# 2021-11-21 19:37:55.568 | INFO     | __main__:parse_data_02:21 - processing page: 64 LEXUS) # 1
# 2021-11-21 19:37:55.990 | INFO     | __main__:parse_data_02:21 - processing page: 65 LEXUS) # 1
# 2021-11-21 19:37:56.607 | INFO     | __main__:parse_data_02:21 - processing page: 66 LEXUS) # 1
# 2021-11-21 19:37:56.842 | INFO     | __main__:parse_data_02:21 - processing page: 67 LEXUS) # 1
# 2021-11-21 19:37:57.065 | INFO     | __main__:parse_data_02:21 - processing page: 68 LEXUS) # 1
# 2021-11-21 19:37:57.532 | INFO     | __main__:parse_data_02:21 - processing page: 69 LEXUS) # 1
# 2021-11-21 19:37:57.758 | INFO     | __main__:parse_data_02:21 - processing page: 70 LEXUS) # 1
# 2021-11-21 19:37:58.347 | INFO     | __main__:parse_data_02:21 - processing page: 71 LEXUS) # 1
# 2021-11-21 19:37:58.626 | INFO     | __main__:parse_data_02:21 - processing page: 72 LEXUS) # 1
# 2021-11-21 19:37:59.069 | INFO     | __main__:parse_data_02:21 - processing page: 73 LEXUS) # 1
# 2021-11-21 19:37:59.782 | INFO     | __main__:parse_data_02:21 - processing page: 74 LEXUS) # 1
# 2021-11-21 19:38:00.394 | INFO     | __main__:parse_data_02:21 - processing page: 75 LEXUS) # 1
# 2021-11-21 19:38:00.608 | INFO     | __main__:parse_data_02:21 - processing page: 76 LEXUS) # 1
# 2021-11-21 19:38:00.857 | INFO     | __main__:parse_data_02:21 - processing page: 77 LEXUS) # 1
# 2021-11-21 19:38:01.195 | INFO     | __main__:parse_data_02:21 - processing page: 78 LEXUS) # 1
# 2021-11-21 19:38:01.725 | INFO     | __main__:parse_data_02:21 - processing page: 79 LEXUS) # 1
# 2021-11-21 19:38:02.071 | INFO     | __main__:parse_data_02:21 - processing page: 80 LEXUS) # 1
# 2021-11-21 19:38:02.503 | INFO     | __main__:parse_data_02:21 - processing page: 81 LEXUS) # 1
# 2021-11-21 19:38:02.928 | INFO     | __main__:parse_data_02:21 - processing page: 82 LEXUS) # 1
# 2021-11-21 19:38:03.192 | INFO     | __main__:parse_data_02:21 - processing page: 83 LEXUS) # 1
# 2021-11-21 19:38:03.476 | INFO     | __main__:parse_data_02:21 - processing page: 84 LEXUS) # 1
# 2021-11-21 19:38:03.700 | INFO     | __main__:parse_data_02:21 - processing page: 85 LEXUS) # 1
# 2021-11-21 19:38:04.236 | INFO     | __main__:parse_data_02:21 - processing page: 86 LEXUS) # 1
# 2021-11-21 19:38:04.902 | INFO     | __main__:parse_data_02:21 - processing page: 87 LEXUS) # 1
# 2021-11-21 19:38:05.822 | INFO     | __main__:parse_data_02:21 - processing page: 88 LEXUS) # 1
# 2021-11-21 19:38:06.218 | INFO     | __main__:parse_data_02:21 - processing page: 89 LEXUS) # 1
# 2021-11-21 19:38:06.657 | INFO     | __main__:parse_data_02:21 - processing page: 90 LEXUS) # 1
# 2021-11-21 19:38:07.257 | INFO     | __main__:parse_data_02:21 - processing page: 91 LEXUS) # 1
# 2021-11-21 19:38:07.666 | INFO     | __main__:parse_data_02:21 - processing page: 92 LEXUS) # 1
# 2021-11-21 19:38:08.179 | INFO     | __main__:parse_data_02:21 - processing page: 93 LEXUS) # 1
# 2021-11-21 19:38:08.451 | INFO     | __main__:parse_data_02:21 - processing page: 94 LEXUS) # 1
# 2021-11-21 19:38:08.750 | INFO     | __main__:parse_data_02:21 - processing page: 95 LEXUS) # 1
# 2021-11-21 19:38:09.216 | INFO     | __main__:parse_data_02:21 - processing page: 96 LEXUS) # 1
# 2021-11-21 19:38:09.647 | INFO     | __main__:parse_data_02:21 - processing page: 97 LEXUS) # 1
# 2021-11-21 19:38:10.245 | INFO     | __main__:parse_data_02:21 - processing page: 98 LEXUS) # 1
# 2021-11-21 19:38:10.860 | INFO     | __main__:parse_data_02:21 - processing page: 99 LEXUS) # 1
# 2021-11-21 19:38:11.207 | INFO     | __main__:write_to_csv:13 - writing out211120/data.csv, содержащий 85 записей
# 2021-11-21 19:38:11.220 | INFO     | __main__:parse_data_02:43 - parsing successfully finished

# %%
df = pd.read_csv('out211120/data_1200.csv')
for n in ['data-1201.csv', 'data-1202.csv', 'data-1203.csv']:
    df1 = pd.read_csv('out211120/'+n)
    df = df.append(df1)
    df.drop_duplicates(['sell_id'], inplace=True)
df.reset_index(inplace=True)

# %%
df.shape
# Out:
# (42046, 35)

# %%
df.head()
# Out:
#    index           bodyType brand  \
# 0      0  Внедорожник 5 дв.   BMW
# 1      1              Седан   BMW
# 2      2              Седан   BMW
# 3      3               Купе   BMW
# 4      4              Седан   BMW
#
#                                              car_url   color  \
# 0  https://auto.ru/cars/used/sale/bmw/x5/11057182...  040001
# 1  https://auto.ru/cars/used/sale/bmw/3er/1106015...  040001
# 2  https://auto.ru/cars/used/sale/bmw/m5/11057329...  CACECB
# 3  https://auto.ru/cars/used/sale/bmw/3er/1103184...  EE1D19
# 4  https://auto.ru/cars/used/sale/bmw/7er/1105925...  040001
#
#                                   complectation_dict  \
# 0                                        {'id': '0'}
# 1  {'id': '9361242', 'name': '316i SE', 'availabl...
# 2                                        {'id': '0'}
# 3                                        {'id': '0'}
# 4                                        {'id': '0'}
#
#                                          description engineDisplacement  \
# 0  Автомобиль приобретался новым и с тех пор нахо...            3.0 LTR
# 1  Юридически чистый и технически обслуженный авт...            1.6 LTR
# 2  Продажа указанного БМВ осуществляется в формат...            4.4 LTR
# 3  Бмв 316 по документам 1.8\nПо факту был устано...            1.8 LTR
# 4  Автомобиль в достойном состоянии. Чистый, не к...            4.8 LTR
#
#   enginePower location  ... vehicleTransmission    vendor Владельцы  \
# 0     249 N12   Москва  ...           AUTOMATIC  EUROPEAN         2
# 1     136 N12  Щелково  ...           AUTOMATIC  EUROPEAN         3
# 2     600 N12   Москва  ...               ROBOT  EUROPEAN         1
# 3      90 N12   Москва  ...          MECHANICAL  EUROPEAN         4
# 4     367 N12   Москва  ...           AUTOMATIC  EUROPEAN         2
#
#                       Владение        ПТС           Привод  Руль Состояние  \
# 0   {'year': 2017, 'month': 5}   ORIGINAL  ALL_WHEEL_DRIVE  LEFT      True
# 1   {'year': 2020, 'month': 5}   ORIGINAL       REAR_DRIVE  LEFT      True
# 2  {'year': 2014, 'month': 12}   ORIGINAL       REAR_DRIVE  LEFT      True
# 3   {'year': 2017, 'month': 7}  DUPLICATE       REAR_DRIVE  LEFT      True
# 4   {'year': 2019, 'month': 1}   ORIGINAL       REAR_DRIVE  LEFT      True
#
#   Таможня     price
# 0    True   4350000
# 1    True   1420000
# 2    True  80000000
# 3    True    990000
# 4    True    645000
#
# [5 rows x 35 columns]

# %%
df.loc[df.bodyType=='bodytype'].head()
# Out:
# Empty DataFrame
# Columns: [index, bodyType, brand, car_url, color, complectation_dict, description, engineDisplacement, enginePower, location, equipment_dict, fuelType, image, mileage, modelDate, model_info, model_name, name, numberOfDoors, parsing_unixtime, priceCurrency, productionDate, sell_id, super_gen, vehicleConfiguration, vehicleTransmission, vendor, Владельцы, Владение, ПТС, Привод, Руль, Состояние, Таможня, price]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.to_csv('out211120/211121-12brands.csv')

# %%
for n in ['data-360.csv', 'data-361.csv', 'data-362.csv']:
    df1 = pd.read_csv('out211120/'+n)
    df = df.append(df1)
    df.drop_duplicates(['sell_id'], inplace=True)
df.reset_index(inplace=True)
df.shape
# Out:
# (91000, 36)

# %%
df.to_csv('out211120/211121-36brands.csv')

# %% [markdown]
#  ### Предварительные выводы.
#
# Собрано 42к записей по 12 брендам и 91к записей по 36 брендам, что выше результата, предложенного в качестве baseline авторами условий.  Идеи про объединение с унаследованными наборами, пока отложу на стадию возможных улучшений.  Внимание будет сосредоточено на создании собственного baseline MVP.
